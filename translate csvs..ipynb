# %%
import pandas as pd
import numpy as np
pd.set_option("display.max_rows", None, "display.max_columns", None)

# %%
columbia = pd.read_csv("MasterSheet CSVS/Columbia.csv")# student ig, candy, medical conditions
ephrata = pd.read_csv("MasterSheet CSVS/Ephrata.csv")#comments, medical conditions 
lcath = pd.read_csv("MasterSheet CSVS/Lancaster Catholic.csv")#medical conditions, comments
manCent = pd.read_csv("MasterSheet CSVS/Manhiem Central.csv")#medical conditions, comments
manTown = pd.read_csv("MasterSheet CSVS/Manhiem Township.csv")#comments
penn = pd.read_csv("MasterSheet CSVS/Penn Manor.csv")#20 columns
total = [columbia, ephrata, lcath, manCent, manTown, penn]

# %%
def pcol(df):
    print(df.columns.size, df.columns)
# for i in total:
#     pcol(i)
allcols = columbia.columns.tolist()
allcols.append("Comments")

# %%
count =1
for df in total: 
    print(count)
    for c in allcols:
        if c not in df.columns:
            df[c]=np.nan
    df=df.reindex(allcols, axis ="columns")
    count+=1
allcols
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# ['Student Name',
#  'Student Email',
#  'Student Phone',
#  'Student IG',
#  'Favorite Candy',
#  'Birthdate',
#  'Address',
#  'Gender',
#  'Race',
#  'Medical Conditions',
#  'Shirt Size',
#  'Short Size',
#  'Guardian 1 Name',
#  'Guardian 1 Phone',
#  'Guardian 1 Email',
#  'Guardian 1 Occupation',
#  'Guardian 1 Shirt Size',
#  'Guardian 2 Name',
#  'Guardian 2 Phone',
#  'Guardian 2 Email',
#  'Guardian 2 Occupation',
#  'Guardian 2 Shirt Size',
#  'Emergency Contact',
#  'Comments']

# %%
schools = ["Columbia", "Ephrata", "Lancaster Catholic", "Manhiem Central", "Manhiem Township", "Penn Manor"]
for i in range(len(total)):
    total[i]["School"] = schools[i]
alldf = pd.concat(total, ignore_index =True)
alldf
# Out:
#                  Student Name                           Student Email  \
# 0              Alayna Morales     moralesaj1@students.columbiabsd.org
# 1              Andrew Eitnier                 Andrewcolbey@icloud.com
# 2               Ashton Paules       paulesab@students.columbiabsd.org
# 3                Carmen Cayol                  Carmensita1@icloud.com
# 4              Collin McCarty      mccartycp@students.columbiabsd.org
# 5                 Emily Waugh        waughee@students.columbiabsd.org
# 6                 Ereny Hanna              ereny.hanna2022@icloud.com
# 7               Ethan Schmitt              ethanschmitt2022@gmail.com
# 8                Jalen Dobson       Dobsonjv@students.columbiabsd.org
# 9              Jessica Sabino                jessicasab101@icloud.com
# 10              Joy Esannason    esannasonjv@students.columbiabsd.org
# 11                Kylie Aston        astonkr@students.columbiabsd.org
# 12                   Leah Fry                    leahmfry11@gmail.com
# 13               Luke Redding      reddingld@students.columbiabsd.org
# 14            Mackenzie Burke        Burkemp@students.columbiabsd.org
# 15              Morgan Bigler       biglermg@students.columbiabsd.org
# 16                 Noe Moreta                   Dunkzlia572@gmail.com
# 17              Olivia Menard                oliviamenard04@gmail.com
# 18             Robert Footman       Footmanra@student.columbiabsd.org
# 19           Sarah Hollerbush                   Rubybugjr@comcast.net
# 20               Shai Madison                 shaimadison13@gmail.com
# 21         Sidney Berntheizel  berntheizelse@students.columbiabsd.org
# 22              Stephen Huang                 stevochevo021@gmail.com
# 23          Victoria Martinez     martinezvr@students.columbiabsd.org
# 24             Abigail Peters                Abbypeters0310@gmail.com
# 25            Alberto Ramirez                                     NaN
# 26            Alexander Myers                     tombfyre1@yahoo.com
# 27            Amadeus Blandon               Blandonamadeus7@gmail.com
# 28      Angel Gonzalez Garcia            gonzalezangel20213@yahoo.com
# 29              Brynne Lehman                    BCLehman28@gmail.com
# 30           Chrisitan Martin                                     NaN
# 31           Deondra Benhomme                                     NaN
# 32               Devon Litten                                     NaN
# 33             Elijah knowles                 Elijahknowles9@gmai.com
# 34          Elysa Abdelmassih              Elysaabdelmassih@gmail.com
# 35                James Ellis                jaellisje_03@hotmail.com
# 36              Jessica Pratt                  jpthecook123@gmail.com
# 37               Joslyn Rojas                                     NaN
# 38               Leah Kreider                 Brainybaker16@gmail.com
# 39             Lily Patterson                  lilynevaeh@hotmail.com
# 40              Mariam Diallo               Mdmariamdiallo8@gmail.com
# 41               Mariem Hanna                                     NaN
# 42             Marquise Greer                    8014167@gomounts.org
# 43           Nashalee Morales           nashaleemorales1030@gmail.com
# 44              Robert Walker                                     NaN
# 45         Sabrina Zamatayeva                  szamatayev33@gmail.com
# 46              Shawna Martin               shawnapmartinnn@gmail.com
# 47                  Snow Yang                   snowyang022@gmail.com
# 48            Sophia Gonzalez                 malisayang637@gmail.com
# 49             Stanley Wratto                stanleypwratto@gmail.com
# 50               Alexis Baker                   220280006@lchsyes.org
# 51                 Alysa Hile                   221580072@lchsyes.org
# 52          Annalise Kauffman                   221640085@lchsyes.org
# 53               Antonio Cruz                    cruzing717@gmail.com
# 54             Audrey D’Amico                   222420043@lchsyes.org
# 55             Avery Thompson                   221640058@lchsyes.org
# 56               Halle Snopek                   222420037@lchsyes.org
# 57              Isabel Flores                   220500048@lchsyes.org
# 58               Isaiah Caine              isaiahbuscaine36@gmail.com
# 59              Joseph Werhel                   220500148@lchsyes.org
# 60            Karla Henriquez                   222420031@lchsyes.org
# 61             Katherine Lyle                   221580074@lchsyes.org
# 62               Kyle Francis                 kjfrancis2304@gmail.com
# 63               Mya Gonzalez                   222420016@lchsyes.org
# 64         Olivia Del Rosario                   222420013@lchsyes.org
# 65                 Ryan Kukic                   rynokukic@comcast.net
# 66              Shania Crespo                   220164012@lchsyes.org
# 67            Sophia Williams                  2224201956@lchsyes.org
# 68            Alaiyah Moberly              moberlyalaiyah22@gmail.com
# 69           Alexia Sylvester                Sylvester.lexi@gmail.com
# 70               Alexis Young                alexisyoung13@icloud.com
# 71            Audrey Cressler        22CresslerA32@manheimcentral.net
# 72             Barend Oostdam         22OostdamB62@manheimcentral.net
# 73              Bella Harrill              Sophia.i.harrill@gmail.com
# 74            Brandon Ireland                  22IrelandB59@gmail.com
# 75                Dylan Yoder           22yoderd18@manheimcentral.net
# 76               Ethan Dieter          22DieterE55@manheimcentral.net
# 77        Evangeline Guttedar        22Guttedare68@manheimcentral.net
# 78           Gabriel Santiago        22SantiagoG95@manheimcentral.net
# 79          Hannah Whitehouse      22WhitehouseH16@manheimcentral.net
# 80               Irene Turner          22TurnerI22@manheimcentral.net
# 81              Jordan Fisher          22fisherj39@manheimcentral.net
# 82              Kennan Ulrich          22ulrichk99@manheimcentral.net
# 83                Kobe Wilson          22wilsonk32@manheimcentral.net
# 84              LaNaiyah Rowe           zoemakesanentrance@icloud.com
# 85               Larry Marley          22MarleyL82@manheimcentral.net
# 86             Lauren Gerhart         22GerhartL29@manheimcentral.org
# 87                  Lisa Peng                  Lisapeng1064@gmail.com
# 88             Mikayla Martin                 Mamamartin23@icloud.com
# 89                 Neel Patel                   npatel5221@icloud.com
# 90              Sammi Elwakdy         22ElwakdyS27@manheimcentral.org
# 91                Sine Carter                 nenecarter15@icloud.com
# 92              Sophia Armato                fieldhockey694@gmail.com
# 93              Veronica Levy                ronniechicken8@gmail.com
# 94           Alexandra Parise                   aparise13@comcast.net
# 95                 Alina Diaz          2022diazmoal@mtwp.students.net
# 96                 Alina Diaz          2022diazmoal@mtwp.students.net
# 97   Allison Noriega da Costa           alexandradacosta654@gmail.com
# 98                     Altina                                     NaN
# 99              Anaya mccurdy          2022mccurdan@students.mtwp.net
# 100         Anika Ramachandra              anikaramachandra@gmail.com
# 101             Anneyah Ramos           2022ramosan@students.mtwp.net
# 102              Anthony Ivey           Kingivey.anthony123@gmail.com
# 103          Brandon Valverde                  2022valverbr@gmail.com
# 104           Cristina Cortes          2022cortescr@students.mtwp.net
# 105                Emma Moore           2022mooreem@students.mtwp.net
# 106                Esra Savas                  eves.evsa321@gmail.com
# 107             Faith Onchuru                  faithonchuru@gmail.com
# 108      Isabella (Izzy) Cruz              isabellacruz2022@gmail.com
# 109              Isaiah Jones           2022jonesis@students.mtwp.net
# 110               Jay Loughry          2022loughrja@students.mtwp.net
# 111                      Jose                                     NaN
# 112               Lucas Welch                     ljw369199@gmail.com
# 113                 lucian li                    lucianli1@icloud.com
# 114               Matt Torres          2022torresma@students.mtwp.net
# 115             Paloma Rivera              palomarivera2022@gmail.com
# 116               Rachel Herr                     rherr8604@gmail.com
# 117            Raymond Corbin          2022corbinra@students.mtwp.net
# 118             Regan Andreas                  reganandreas@gmail.com
# 119             Ruthza Gerard                  ruthzagerard@gmail.com
# 120               Sena Graver          2022graverse@mtwp.students.net
# 121              Sheron Maxie           2022maxieshastudents.mtwp.net
# 122               Sophia Yost                Sophieyost2022@gmail.com
# 123          Thalissa Ramirez                  Thalissa.r04@yahoo.com
# 124            Aayushma Dulal                     aayushmad@yahoo.com
# 125            Alexa Loercher               alexabloercher@icloud.com
# 126                Ana Musser                    202445@pennmanor.net
# 127            Ashmita gautam                   Gashmita247@gmail.com
# 128          Charlie Gonzalez         Charliegonzalez2980@hotmail.com
# 129               Devin Sauer                    202615@pennmanor.net
# 130              Dylan Wenger                    202565@pennmanor.net
# 131               Ella Layton                    207290@pennmanor.net
# 132                Emma Spong                    202412@pennmanor.net
# 133              Jaiden Lepez                    204386@pennmanor.net
# 134           Jasmine Sanders                     jms205133@gmail.com
# 135            Jesselin Lopez                    207335@pennmanor.net
# 136            Jocelyn Wagner                    202523@pennmanor.net
# 137           Jonathan Medina               johnnymedina532@gmail.com
# 138              Letu Chibssa                 Letuchibssa12@gmail.com
# 139           Madeleine Weber                    202387@pennmanor.net
# 140              Mahara Smith                    202761@pennmanor.net
# 141                 Noe Perez                    208194@pennmanor.net
# 142               Pedro Gomez                    204593@pennmanor.net
# 143               Randy Short                    208450@pennmanor.net
# 144               Randy Short                    208450@pennmanor.net
# 145                  Savannah                    202525@pennmanor.net
# 146             Souka Bonheur                    207516@pennmanor.net
# 147             Sumit Ghimire                    209132@pennamnor.net
#
#                     Student Phone         Student IG  \
# 0                      7174157784    alayna__morales
# 1                      7176693252          _aeitnier
# 2                      7172091487      ashton_paules
# 3                      7176173496        _carmenn.__
# 4                      7178088113  collin_mccarty_14
# 5                      7173141590  rainbow_turtles17
# 6                      6103929636          erenyxoxo
# 7                    717-990-9508  its.ethan.schmitt
# 8                      7177198603       jalentheonly
# 9                      9292049232       _jess._.sab_
# 10                     7173330067       esannasonjoy
# 11                 717- 208- 5766        kylie_aston
# 12                     7179517501       leahh_marie3
# 13                   717-342-7373       lukeredding_
# 14                     7178263985      _kenzieburke_
# 15                   717-468-7165    morgannn.bigler
# 16                     7172089938        noee.moreta
# 17                     7177192847      oliviamenard_
# 18                     7178554797             rf_jr3
# 19                     7172090335    bearskikbear713
# 20                     7173427841       shaiimadison
# 21                     7173425028        sidneybernn
# 22                   717-669-0240        stevo_chevo
# 23                     7174052148                NaN
# 24                     7176639139                NaN
# 25                 (717) 224-8333                NaN
# 26                     7174196842                NaN
# 27                     9172073165                NaN
# 28                   717-271-2544                NaN
# 29                     7177252831                NaN
# 30                 (717) 621-1750                NaN
# 31   deondrabonhomme89@icloud.com                NaN
# 32                 (717) 466-9205                NaN
# 33                     2672210364                NaN
# 34                     7178638078                NaN
# 35                   717 723 0005                NaN
# 36                   (864)7608667                NaN
# 37                 (717) 715-7703                NaN
# 38                   717-468-1102                NaN
# 39                     7173686451                NaN
# 40                     7179841505                NaN
# 41                     7177996481                NaN
# 42                   717-341-7198                NaN
# 43                 (347) 764-4857                NaN
# 44                 (717) 693-2844                NaN
# 45                   936 263 2563                NaN
# 46                  (717)224-1818                NaN
# 47                 (717) 799-9431                NaN
# 48                     7176639081                NaN
# 49                     7174766257                NaN
# 50                     7172712045                NaN
# 51                     7178506006                NaN
# 52                     7179256327                NaN
# 53                     7172246755                NaN
# 54                     7178755768                NaN
# 55                     7179251153                NaN
# 56                     7178268433                NaN
# 57                 (717) 682-4744                NaN
# 58                     7176210576                NaN
# 59                     7175750311                NaN
# 60                     7178263514                NaN
# 61                   717-468-3367                NaN
# 62                     7178473235                NaN
# 63                   717-621-1480                NaN
# 64                   717-984-9366                NaN
# 65                     7177428101                NaN
# 66                     7173817329                NaN
# 67                   717-675-4924                NaN
# 68                     7176904802                NaN
# 69                     7176820396                NaN
# 70                     8145054813                NaN
# 71                     7175724475                NaN
# 72                     7172244837                NaN
# 73                     7177427128                NaN
# 74                     7173719231                NaN
# 75                     7176909753                NaN
# 76                     2232161420                NaN
# 77                     7178440970                NaN
# 78                     7178025881                NaN
# 79                     7172771601                NaN
# 80                     7176182301                NaN
# 81                     7178750579                NaN
# 82                     7174192920                NaN
# 83                     3022749731                NaN
# 84                     7178239391                NaN
# 85                     7179192264                NaN
# 86                     7177427851                NaN
# 87                   717-875-9110                NaN
# 88                     7178922545                NaN
# 89                     7176230121                NaN
# 90                     7174755942                NaN
# 91                     7173815159                NaN
# 92                     7177999441                NaN
# 93                     7178036212                NaN
# 94                     7172056522          3/20/2004
# 95                  (717)984-4023           6/3/2002
# 96                  (717)984-4023           6/3/2002
# 97                     9083570418          6/12/2004
# 98                            NaN                NaN
# 99                     7175758997    January 20 2004
# 100                    7174054657          4/27/2004
# 101                  717-690-4342          9/22/2004
# 102                    7173008381         11/18/2003
# 103                    7173801076          6/13/2004
# 104                    7177017562          9/14/2004
# 105                  717 875 3729          9/20/2004
# 106                    7173143762          8/17/2004
# 107                  717-348-5457         10/23/2003
# 108                    7177231588           9/7/2004
# 109                  717-917-9991     July 28th 2004
# 110                (717)-844-3580          5/14/2004
# 111                 (717)598-3217                NaN
# 112                  717-892-9219          3/25/2004
# 113                  717-666-5538          11/1/2003
# 114                    7175387058         12/23/2003
# 115                  717-314-7373           5/6/2004
# 116                 (717)875-4804           8/6/2004
# 117                    7179929026         10/17/2003
# 118                    7176152447           3/4/2004
# 119                    7176156424          10/6/2003
# 120                           NaN                NaN
# 121                    7173803182           9/9/2003
# 122                    7174352659          5/12/2004
# 123                    7177428888          5/30/2004
# 124                  717-696-9371                NaN
# 125                 (717)669-6611                NaN
# 126                  717-406-9117                NaN
# 127                    7174134013                NaN
# 128                    7178472630                NaN
# 129                    7178929882                NaN
# 130                    7173308464                NaN
# 131                    7175863128                NaN
# 132                    7174750517                NaN
# 133                  223-216-1283                NaN
# 134                    7177991214                NaN
# 135                  717-342-9777                NaN
# 136                (717) 606-8629                NaN
# 137                    7174681140                NaN
# 138                    7174192180                NaN
# 139                    7176178024                NaN
# 140                  717-327-1105                NaN
# 141                  717-615-0187                NaN
# 142                    7172035418                NaN
# 143                    7176175716                NaN
# 144                    7176175716                NaN
# 145                    7174065568                NaN
# 146                    7178756034                NaN
# 147                    9294619225                NaN
#
#                                  Favorite Candy           Birthdate  \
# 0                                        Reeses            2-Sep-03
# 1                                        Reeses           6/24/2003
# 2                         Any kind of chocolate          11/10/2003
# 3                                      Skittles          12/20/2003
# 4                                      Snickers            6/4/2004
# 5                                          Twix           1/17/2004
# 6                                           NaN            4/6/2004
# 7                                      Smarties           1/22/2004
# 8                                   Gum or twix           17-Jul-04
# 9                                Fruit roll ups           10/8/2003
# 10                                          NaN  December 23rd 2003
# 11                                          M&M      August 11 2004
# 12                                   Lemonheads        June 28 2004
# 13                                  Hershey bar          10/16/2003
# 14                              Sour patch kids          11/21/2003
# 15                                  Gummy bears            7/1/2004
# 16                                       Reeses           8/20/2004
# 17                                     Snickers           5/20/2004
# 18                                     Snickers           6/19/2004
# 19                                  Sweet tarts           7/13/2004
# 20                                       Reeses           10/1/2003
# 21                                  Peach rings           8/19/2004
# 22                                          NaN            9/3/2003
# 23                                       Mounds            3-Jul-04
# 24                                          NaN          10/31/2003
# 25                                          NaN                 NaN
# 26                                          NaN       June 4th 2004
# 27                                          NaN           8/26/2004
# 28                                          NaN          12/13/2003
# 29                                          NaN          10/28/2003
# 30                                          NaN                 NaN
# 31                                          NaN                 NaN
# 32                                          NaN                 NaN
# 33                                          NaN           6/13/2004
# 34                                          NaN            9/6/2004
# 35                                          NaN          05 20 2004
# 36                                          NaN          12/30/2003
# 37                                          NaN                 NaN
# 38                                          NaN           7/16/2004
# 39                                          NaN           6/20/2004
# 40                                          NaN           4/28/2004
# 41                                          NaN                 NaN
# 42                                          NaN          12/31/2003
# 43                                          NaN                 NaN
# 44                                          NaN                 NaN
# 45                                          NaN           12/3/2003
# 46                                          NaN          11/21/2003
# 47                                          NaN                 NaN
# 48                                          NaN           6/11/2004
# 49                                          NaN           3/23/2003
# 50                                          NaN           2/18/2004
# 51                                          NaN          10/21/2003
# 52                                          NaN          11/10/2003
# 53                                          NaN           21-Sep-03
# 54                                          NaN           10/2/2003
# 55                                          NaN           5/30/2004
# 56                                          NaN           8/27/2003
# 57                                          NaN            9-Dec-03
# 58                                          NaN           3/24/2003
# 59                                          NaN          10/17/2003
# 60                                          NaN          11/24/2003
# 61                                          NaN           6/23/2004
# 62                                          NaN           1/18/2004
# 63                                          NaN           11/4/2004
# 64                                          NaN            2-Aug-04
# 65                                          NaN            9/2/2003
# 66                                          NaN            2/6/2004
# 67                                          NaN            1/3/2004
# 68                                          NaN            9/1/2003
# 69                                          NaN           2/19/2004
# 70                                          NaN          10/30/2003
# 71                                          NaN           5/12/2004
# 72                                          NaN           3/20/2004
# 73                                          NaN           11/8/2003
# 74                                          NaN           4/30/2004
# 75                                          NaN          10/27/2003
# 76                                          NaN          11/22/2003
# 77                                          NaN           4/27/2004
# 78                                          NaN                 NaN
# 79                                          NaN           8/17/2004
# 80                                          NaN           4/24/2004
# 81                                          NaN           6/16/2004
# 82                                          NaN           10/7/2004
# 83                                          NaN                 NaN
# 84                                          NaN           5/28/2004
# 85                                          NaN           9/11/2003
# 86                                          NaN           4/12/2003
# 87                                          NaN            5/5/2003
# 88                                          NaN           2/23/2004
# 89                                          NaN           8/24/2004
# 90                                          NaN                 NaN
# 91                                          NaN           3/12/2004
# 92                                          NaN            6/9/2004
# 93                                          NaN                 NaN
# 94                1159 Suffolk Drive Lititz, PA                 NaN
# 95                             451 Holbrook ave                 NaN
# 96                             451 Holbrook ave                 NaN
# 97                          366 greenview drive                 NaN
# 98      302 E Roseville Rd, Lancaster, PA 17601                 NaN
# 99                            1918northbrook dr                 NaN
# 100  1054 Whitemarsh Drive, Lancaster, PA 17601                 NaN
# 101                                148 buch ave                 NaN
# 102                         2222 Middlegreen Ct                 NaN
# 103                              149 Warren Way                 NaN
# 104                            426 Haverhill Rd                 NaN
# 105                               831 Helen Ave                 NaN
# 106      2148 Sherwal Avenue Lancaster PA 17601                 NaN
# 107             342 E Oregon Rd Lititz Pa 17543                 NaN
# 108                       1272 Cobblestone Lane                 NaN
# 109         128 Rutledge Ave Lancaster PA 17601                 NaN
# 110                             619 Chatham Way                 NaN
# 111                                         NaN                 NaN
# 112        351 Portland Place, Lititz, PA 17543                 NaN
# 113                  2608 Oregon Pike Lititz PA                 NaN
# 114                             908 Mayer Place                 NaN
# 115         375 Arbor Road, Lancaster, PA 17601                 NaN
# 116                        800 Wallingford Road                 NaN
# 117                             2949 Aster Lane                 NaN
# 118                                113 Pulte Rd                 NaN
# 119               819 Fountain Ave lancaster PA                 NaN
# 120                                         NaN                 NaN
# 121                        546 candle wyck road                 NaN
# 122                             320 Millpond Dr                 NaN
# 123                           30 Camellia Court                 NaN
# 124                                         NaN           2/24/2004
# 125                                         NaN           3/25/2004
# 126                                         NaN           5/28/2004
# 127                                         NaN            1/4/2004
# 128                                         NaN          10/29/2003
# 129                                         NaN          12/25/2003
# 130                                         NaN           9/25/2004
# 131                                         NaN           10/3/2003
# 132                                         NaN            4/1/2004
# 133                                         NaN           6/14/2004
# 134                                         NaN           1/26/2004
# 135                                         NaN           7/22/2004
# 136                                         NaN           1/20/2004
# 137                                         NaN            8/1/2004
# 138                                         NaN           9/12/2003
# 139                                         NaN           11/2/2003
# 140                                         NaN          12/26/2003
# 141                                         NaN            2/6/2004
# 142                                         NaN           1/14/2004
# 143                                         NaN           11/4/2003
# 144                                         NaN           11/4/2003
# 145                                         NaN           1/13/2004
# 146                                         NaN           9/29/2003
# 147                                         NaN           3/24/2004
#
#                                                Address  Gender  \
# 0                                   921 Ironville Pike  Female
# 1                    113 Locust St. Columbia, Pa 17512    Male
# 2                  535 Maple Street Columbia, PA 17512    Male
# 3                                     339 Union Street  Female
# 4                                    1020 central ave.    Male
# 5                                    535 Poplar Street  Female
# 6                  206 Walnut Street Columbia PA 17512  Female
# 7                      311 N 7th St, Columbia PA 17512    Male
# 8                                    129 N. 3rd Street    Male
# 9                                     1266 Staman Lane  female
# 10                                 22 south 5th street  Female
# 11                                       739 locust st  female
# 12                                113 south 8th street  Female
# 13                1241 Hereford Dr. Columbia, PA 17512    Male
# 14                                        804 Plane St  Female
# 15                                 1010 Central Avenue  Female
# 16                                        234 S 2nd st    Male
# 17                      806 Walnut Street, Columbia PA  female
# 18                                         52 S 9th St    Male
# 19                827 Chestnut street Columbia pa17512       F
# 20                                       716, Plane St  Female
# 21                                 1421 Ironville Pike  female
# 22                                   526 WALNUT STREET    Male
# 23                                   552 Walnut street  Female
# 24                     106 mt. Olive Lane, ephrata, Pa  Female
# 25                                 315 Washington Ave.    Male
# 26                241 park avenue Ephrata Pennsylvania    Male
# 27                                 45 autumn blaze way    Male
# 28                                  126 mount olive ln    Male
# 29                                     111 Forry Drive  Female
# 30                                   102 Linda Terrace     NaN
# 31                            83 Irene Ave. Ephrata PA  Female
# 32                                    24 N. Market St.     NaN
# 33                               1228 pleasent view rd    Male
# 34                         15 Fulton st Akron pa 17501  Female
# 35                                  608 Glenwood Drive    Male
# 36                                  12 Summerlyn Drive  Female
# 37                              31 S. Six St. Akron PA     NaN
# 38              159 West King Street Ephrata, PA 17522  Female
# 39                             50 Kings Court, Ephrata  Female
# 40                          53 ridge avenue Ephrata pa  Female
# 41                                 711 broad St. Akron  Female
# 42                         North seven street 202 unit    Male
# 43                         36 E. Walnut St. Ephrata PA     NaN
# 44                                 412A East Fulton st    Male
# 45                     645 Hopeland rd Lititz pa 17543  Female
# 46                        1361 west main st ephrata pa  Female
# 47                         2465 W. Main St. Ephrata PA  Female
# 48                     40 Agape Drive Ephrata PA 17522  Female
# 49                           1706 W Main St Ephrata pa    Male
# 50              160A Harristown Road Paradise PA 17562  Female
# 51                   643 Franklin St Columbia pa 17512  Female
# 52              1224 Fremont Street Lancaster PA 17603  Female
# 53                                      382 Holly Lane    Male
# 54        30 Greystone Circle, Willow Street PA, 17584  Female
# 55                                 738 hamilton street  Female
# 56                                  2009 Robindale Ave  Female
# 57              341 Valley Road, Millersville PA 17551  Female
# 58                                    318 Charles Road    Male
# 59                                1344 Fieldstead Lane    Male
# 60                323 talbot circle lancaster pa 17603  Female
# 61           1336 Donegal Creek Rd, Columbia PA, 17512  Female
# 62              78 Grayson Avenue, East Earl, PA 17519    Male
# 63                                 223 pennshire drive  Female
# 64                                 223 Pennshire Drive  Female
# 65                  255 Dogwood Drive Elizabethtown PA    Male
# 66            703 E. Strawberry St. Lancaster PA 17602  Female
# 67                257 Coachman Lane, Palmyra, PA 17078  Female
# 68                              404 Elm Road Lititz PA  Female
# 69                        6033 Bayberry Ave Manheim PA  Female
# 70                                       2090 Baker Rd  Female
# 71                                    140 W Stiegel St  Female
# 72                       460 Charles Drive Manheim, PA    Male
# 73            558 E Pleasantview Rd. Manheim, pa 17545  Female
# 74                              114 North Grant Street    Male
# 75               1725 Mountain Road, Manheim, PA 17545    Male
# 76                                     166 N. Main. ST    Male
# 77                          446 Zachary Dr, Manheim Pa  Female
# 78        6181 Mountain View Dr Chambersburg, PA 17202    Male
# 79                 5233 Summerfield Drive Mount Joy PA  Female
# 80                                 53 Hemlock Acres Ct  Female
# 81                              1867 Mastersonville Rd  Female
# 82                                         12 Maple Dr    Male
# 83                                     356cedar hollow    Male
# 84                                   140 Coleman Alley  Female
# 85                 739 North Pine St, 17545 Manheim Pa    Male
# 86                  41 Fence Row Lane Manheim PA 17545  Female
# 87                1064 Willow Creek Drive Mount Joy PA  Female
# 88                              1309 Heatherwood Drive  Female
# 89        5221 Summerfield Drive, Mount Joy, 17552, PA    Male
# 90                                                 NaN    Male
# 91                                     568 Hi View Dr.  Female
# 92                 409 Orchard Lane, Manheim, PA 17545  Female
# 93                                                 NaN  Female
# 94                                               White       L
# 95                                            Hispanic      XS
# 96                                            Hispanic      XS
# 97                                             Unknown       M
# 98                                                 NaN       M
# 99                                            Biracial       M
# 100                                              Asian       M
# 101                                        Puertorican       S
# 102                                   African American       L
# 103                                             Latino       M
# 104                                     Mixed (Latinx)       L
# 105                                              White       M
# 106                                          Caucasian       L
# 107                                   African American       M
# 108                                              White       M
# 109                                   African American       M
# 110                                              White       L
# 111                                                NaN       L
# 112                                          caucasian       L
# 113                           CaucAsian or Asian/White      XL
# 114                                      white/spanish       M
# 115              Hispanic (Puerto Rican) and Caucasian       S
# 116                                              White       L
# 117                                           Hispanic       L
# 118                                              White       L
# 119                                              black       M
# 120                                                NaN       L
# 121                             Black and Puerto Rican       L
# 122                                   Latina/Caucasian       L
# 123                                           Hispanic       M
# 124              68 Glen Oaks Drive Lancaster PA 17603  Female
# 125                                   2292 franklin rd  Female
# 126            1005 Hearthstone Rd Lancaster, PA 17603  Female
# 127                                   2754 Weston road  Female
# 128                                  133 Wellington Rd    Male
# 129                                   201 Albright Ave    Male
# 130        115 banyan circle drive, Lancaster Pa 17603    Male
# 131          1009 Stonemanor Drive Lancaster PA, 17603  Female
# 132                     5 Centre Dr Conestoga PA 17516  Female
# 133                       107 Perry lane mountville PA    Male
# 134                                  208 Yorkshire Way  Female
# 135                                  3752 Columbia ave  Female
# 136                         217 Acorn Lane, Mountville  Female
# 137                                 622 Woodhall Drive    Male
# 138                                     395 hampden Dr  Female
# 139                                      11 Kready Ave  Female
# 140                                   11 Landis Avenue  Female
# 141                  397 hampden dr Lancaster pa 17603    Male
# 142                               104 Banyan Circle Dr    Male
# 143                                       31 Manor ave    Male
# 144                                       31 Manor ave    Male
# 145                        29 autumn way willow street  Female
# 146                               887 Central Manor Rd  Female
# 147  240 Stone Mill Rd, Apt E108, Lancaster, PA, 17603    Male
#
#                                          Race  \
# 0                             white/ hispanic
# 1                                       White
# 2                                       White
# 3                                    Hispanic
# 4                                       White
# 5                                       White
# 6                                    Egyptian
# 7                                       White
# 8                                 Black/White
# 9                           hispanic / latina
# 10                           African American
# 11                                      white
# 12                                  Caucasian
# 13                                  Caucasian
# 14                                  Caucasian
# 15                                      White
# 16                           African american
# 17                                      white
# 18                           African American
# 19                                  Caucasian
# 20                                      Black
# 21                                      white
# 22                                      Asian
# 23                                   Hispanic
# 24                                      White
# 25                                   Hispanic
# 26                                  Caucasian
# 27                                   Hispanic
# 28                                   Hispanic
# 29                            White/Caucasian
# 30                                        NaN
# 31                              Black/African
# 32                                        NaN
# 33                                      White
# 34                                  Caucasian
# 35                                      White
# 36                                Black/white
# 37                                        NaN
# 38                                   Hispanic
# 39                            Caucasian/White
# 40                           African american
# 41                                        NaN
# 42                                        NaN
# 43                                   Hispanic
# 44                                        NaN
# 45                              White/Russian
# 46                          Belizean/American
# 47                                        NaN
# 48                                      Asian
# 49                                      Black
# 50                                  Caucasian
# 51                           African American
# 52                             white/hispanic
# 53                    Puerto Rican (Hispanic)
# 54                                  Caucasian
# 55                                      white
# 56                                      White
# 57                     Hispanic, Puerto Rican
# 58             African American and Caucasian
# 59                                  Asian-ish
# 60                                     latina
# 61                                      White
# 62                                      White
# 63                            hispanic/latina
# 64                  Filipino and Puerto Rican
# 65                                      White
# 66                                   Hispanic
# 67                                      White
# 68                                      Mixed
# 69                                  Caucasian
# 70                                      White
# 71                                  Caucasian
# 72                                  Caucasian
# 73                                      White
# 74                                  Caucasian
# 75                                  Caucasian
# 76                                      white
# 77                                      Asian
# 78                                        NaN
# 79                                  Caucasian
# 80                                      White
# 81                                  Caucasian
# 82                                      White
# 83                                      Black
# 84                             Black/Hispanic
# 85                           African American
# 86                                      White
# 87                                      Asian
# 88                            Black and white
# 89                    Asian (Indian) American
# 90                                        NaN
# 91                     Puerto Rican and Black
# 92                                      Asian
# 93                                        NaN
# 94                                          M
# 95                                          S
# 96                                          S
# 97                                          M
# 98                                          L
# 99                                          M
# 100                                         L
# 101                                         M
# 102                                         L
# 103                                         M
# 104                                         L
# 105                                         M
# 106                                         L
# 107                                         M
# 108                                         M
# 109                                         M
# 110                                         M
# 111                                       NaN
# 112                                         M
# 113                                         L
# 114                                         L
# 115                                         S
# 116                                         L
# 117                                         L
# 118                                         L
# 119                                         L
# 120                                       NaN
# 121                                         M
# 122                                         L
# 123                                         M
# 124                                     Asian
# 125                                 Caucasian
# 126                                  Hispanic
# 127                                     Asain
# 128                                  Hispanic
# 129                                  American
# 130                           Hispanic, White
# 131                    Black/African American
# 132                                      Asia
# 133                                  Hispanic
# 134                              Black, White
# 135                                  Hispanic
# 136                          African American
# 137                                  Hispanic
# 138                             Black/African
# 139                                 caucasian
# 140  Biracial: African American and Caucasian
# 141                                  Hispanic
# 142                                  Hispanic
# 143                           black and white
# 144                           black and white
# 145                        white/puerto rican
# 146                                   Haitian
# 147                                     Asian
#
#                                     Medical Conditions          Shirt Size  \
# 0                                                  NaN                   M
# 1    Lexapro for anxiety, Albuteral inhaler for sea...                 XXL
# 2                                                  NaN                   M
# 3                                                  NaN                   S
# 4                                                  NaN                   L
# 5                               occasional nose bleeds                   L
# 6                                                  NaN                   S
# 7                                                  NaN                   L
# 8                              Asthma, carries inhaler                   M
# 9                                                  NaN                   M
# 10                               Asthma inhaler as PRN                 XXL
# 11                                                 NaN                   L
# ...
# 35              Ephrata                                                NaN
# 36              Ephrata                                                NaN
# 37              Ephrata                                                NaN
# 38              Ephrata                                                NaN
# 39              Ephrata                                                NaN
# 40              Ephrata                                                NaN
# 41              Ephrata                                                NaN
# 42              Ephrata                                                NaN
# 43              Ephrata                                                NaN
# 44              Ephrata                                                NaN
# 45              Ephrata                                                NaN
# 46              Ephrata                                                NaN
# 47              Ephrata                                                NaN
# 48              Ephrata                                                NaN
# 49              Ephrata                                                NaN
# 50   Lancaster Catholic                                                NaN
# 51   Lancaster Catholic                                                NaN
# 52   Lancaster Catholic                                                NaN
# 53   Lancaster Catholic                                                NaN
# 54   Lancaster Catholic                                                NaN
# 55   Lancaster Catholic                                                NaN
# 56   Lancaster Catholic                                                NaN
# 57   Lancaster Catholic                                                NaN
# 58   Lancaster Catholic                                                NaN
# 59   Lancaster Catholic                                                NaN
# 60   Lancaster Catholic                                                NaN
# 61   Lancaster Catholic                                                NaN
# 62   Lancaster Catholic                                                NaN
# 63   Lancaster Catholic                                                NaN
# 64   Lancaster Catholic                                                NaN
# 65   Lancaster Catholic                                                NaN
# 66   Lancaster Catholic                                                NaN
# 67   Lancaster Catholic                                                NaN
# 68      Manhiem Central                                                NaN
# 69      Manhiem Central                                                NaN
# 70      Manhiem Central                                                NaN
# 71      Manhiem Central                                                NaN
# 72      Manhiem Central                                                NaN
# 73      Manhiem Central                                                NaN
# 74      Manhiem Central                                                NaN
# 75      Manhiem Central                                                NaN
# 76      Manhiem Central                                                NaN
# 77      Manhiem Central                                                NaN
# 78      Manhiem Central                                                NaN
# 79      Manhiem Central                                                NaN
# 80      Manhiem Central                                                NaN
# 81      Manhiem Central                                                NaN
# 82      Manhiem Central                                                NaN
# 83      Manhiem Central                                                NaN
# 84      Manhiem Central                                                NaN
# 85      Manhiem Central                                                NaN
# 86      Manhiem Central                                                NaN
# 87      Manhiem Central                                                NaN
# 88      Manhiem Central                                                NaN
# 89      Manhiem Central                                                NaN
# 90      Manhiem Central                                                NaN
# 91      Manhiem Central                                                NaN
# 92      Manhiem Central                                                NaN
# 93      Manhiem Central                                                NaN
# 94     Manhiem Township                                             Female
# 95     Manhiem Township                                             Female
# 96     Manhiem Township                                             Female
# 97     Manhiem Township                                             Female
# 98     Manhiem Township                                                NaN
# 99     Manhiem Township                                             Female
# 100    Manhiem Township                                             Female
# 101    Manhiem Township                                             Female
# 102    Manhiem Township                                               Male
# 103    Manhiem Township                                               Male
# 104    Manhiem Township                                             Female
# 105    Manhiem Township                                             Female
# 106    Manhiem Township                                             Female
# 107    Manhiem Township                                             Female
# 108    Manhiem Township                                             Female
# 109    Manhiem Township                                               male
# 110    Manhiem Township  They/Them (but not out so please keep that on ...
# 111    Manhiem Township                                                NaN
# 112    Manhiem Township                                               Male
# 113    Manhiem Township                                               Male
# 114    Manhiem Township                                               male
# 115    Manhiem Township                                             Female
# 116    Manhiem Township                          Female (she/her pronouns)
# 117    Manhiem Township                                               Male
# 118    Manhiem Township                                             Female
# 119    Manhiem Township                                             female
# 120    Manhiem Township                                                NaN
# 121    Manhiem Township                                               Male
# 122    Manhiem Township                                                  F
# 123    Manhiem Township                                             Female
# 124          Penn Manor                                                NaN
# 125          Penn Manor                                                NaN
# 126          Penn Manor                                                NaN
# 127          Penn Manor                                                NaN
# 128          Penn Manor                                                NaN
# 129          Penn Manor                                                NaN
# 130          Penn Manor                                                NaN
# 131          Penn Manor                                                NaN
# 132          Penn Manor                                                NaN
# 133          Penn Manor                                                NaN
# 134          Penn Manor                                                NaN
# 135          Penn Manor                                                NaN
# 136          Penn Manor                                                NaN
# 137          Penn Manor                                                NaN
# 138          Penn Manor                                                NaN
# 139          Penn Manor                                                NaN
# 140          Penn Manor                                                NaN
# 141          Penn Manor                                                NaN
# 142          Penn Manor                                                NaN
# 143          Penn Manor                                                NaN
# 144          Penn Manor                                                NaN
# 145          Penn Manor                                                NaN
# 146          Penn Manor                                                NaN
# 147          Penn Manor                                                NaN
#
#     Gurdian 1 Occupation Gurdian 1 Shirt Size
# 0                    NaN                  NaN
# 1                    NaN                  NaN
# 2                    NaN                  NaN
# 3                    NaN                  NaN
# 4                    NaN                  NaN
# 5                    NaN                  NaN
# 6                    NaN                  NaN
# 7                    NaN                  NaN
# 8                    NaN                  NaN
# 9                    NaN                  NaN
# 10                   NaN                  NaN
# 11                   NaN                  NaN
# 12                   NaN                  NaN
# 13                   NaN                  NaN
# 14                   NaN                  NaN
# 15                   NaN                  NaN
# 16                   NaN                  NaN
# 17                   NaN                  NaN
# 18                   NaN                  NaN
# 19                   NaN                  NaN
# 20                   NaN                  NaN
# 21                   NaN                  NaN
# 22                   NaN                  NaN
# 23                   NaN                  NaN
# 24                   NaN                  NaN
# 25                   NaN                  NaN
# 26                   NaN                  NaN
# 27                   NaN                  NaN
# 28                   NaN                  NaN
# 29                   NaN                  NaN
# 30                   NaN                  NaN
# 31                   NaN                  NaN
# 32                   NaN                  NaN
# 33                   NaN                  NaN
# 34                   NaN                  NaN
# 35                   NaN                  NaN
# 36                   NaN                  NaN
# 37                   NaN                  NaN
# 38                   NaN                  NaN
# 39                   NaN                  NaN
# 40                   NaN                  NaN
# 41                   NaN                  NaN
# 42                   NaN                  NaN
# 43                   NaN                  NaN
# 44                   NaN                  NaN
# 45                   NaN                  NaN
# 46                   NaN                  NaN
# 47                   NaN                  NaN
# 48                   NaN                  NaN
# 49                   NaN                  NaN
# 50                   NaN                  NaN
# 51                   NaN                  NaN
# 52                   NaN                  NaN
# 53                   NaN                  NaN
# 54                   NaN                  NaN
# 55                   NaN                  NaN
# 56                   NaN                  NaN
# 57                   NaN                  NaN
# 58                   NaN                  NaN
# 59                   NaN                  NaN
# 60                   NaN                  NaN
# 61                   NaN                  NaN
# 62                   NaN                  NaN
# 63                   NaN                  NaN
# 64                   NaN                  NaN
# 65                   NaN                  NaN
# 66                   NaN                  NaN
# 67                   NaN                  NaN
# 68                   NaN                  NaN
# 69                   NaN                  NaN
# 70                   NaN                  NaN
# 71                   NaN                  NaN
# 72                   NaN                  NaN
# 73                   NaN                  NaN
# 74                   NaN                  NaN
# 75                   NaN                  NaN
# 76                   NaN                  NaN
# 77                   NaN                  NaN
# 78                   NaN                  NaN
# 79                   NaN                  NaN
# 80                   NaN                  NaN
# 81                   NaN                  NaN
# 82                   NaN                  NaN
# 83                   NaN                  NaN
# 84                   NaN                  NaN
# 85                   NaN                  NaN
# 86                   NaN                  NaN
# 87                   NaN                  NaN
# 88                   NaN                  NaN
# 89                   NaN                  NaN
# 90                   NaN                  NaN
# 91                   NaN                  NaN
# 92                   NaN                  NaN
# 93                   NaN                  NaN
# 94                   NaN           7174750435
# 95            Iris Frias         717-330-6828
# 96            Iris Frias         717-330-6828
# 97        Maria Da Costa           7175380966
# 98                   NaN                  NaN
# 99          Dale mccurdy           7175873045
# 100    Sunil Ramachandra           7174090972
# 101                  NaN                  NaN
# 102                  NaN                  NaN
# 103        Juan Valverde         717-538-7677
# 104          Luis Cortes           9732342930
# 105       Alain Reynolds         717 203 9660
# 106          Orhan Savas           2672297831
# 107        Cosmas Marisi           7172833849
# 108                  NaN                  NaN
# 109                  NaN                  NaN
# 110                  NaN                  NaN
# 111                  NaN                  NaN
# 112           Jill Welch         717-283-5615
# 113         Sarah Popdan         717-984-8566
# 114          Mike Torres           7172089314
# 115         Ramón Rivera         717-606-8609
# 116                  NaN                  NaN
# 117       Raymond Corbin           7184159574
# 118         Paul Andreas           7176152443
# 119      Zacharie Gerard                  NaN
# 120                  NaN                  NaN
# 121       Chrisden White         717-406-4513
# 122          Andrew Yosr           7173271469
# 123     Thaddeus Ramirez           7174353147
# 124                  NaN                  NaN
# 125                  NaN                  NaN
# 126                  NaN                  NaN
# 127                  NaN                  NaN
# 128                  NaN                  NaN
# 129                  NaN                  NaN
# 130                  NaN                  NaN
# 131                  NaN                  NaN
# 132                  NaN                  NaN
# 133                  NaN                  NaN
# 134                  NaN                  NaN
# 135                  NaN                  NaN
# 136                  NaN                  NaN
# 137                  NaN                  NaN
# 138                  NaN                  NaN
# 139                  NaN                  NaN
# 140                  NaN                  NaN
# 141                  NaN                  NaN
# 142                  NaN                  NaN
# 143                  NaN                  NaN
# 144                  NaN                  NaN
# 145                  NaN                  NaN
# 146                  NaN                  NaN
# 147                  NaN                  NaN

# %%
def splitname(df, name):
    df1 = df[name].str.split(" ",expand=True,)
    df1.columns = ['{}{}'.format(name, x+1) for x in df1.columns]
    df = df.join(df1)
    name2 = name+'2'
    name3 = name+'3'
    name4 = name+'4'
    if name3 in df:
        check = df[df[name3].notnull()].index.tolist()
        print(name3, '-',check)
        
        for i in check:
            x = df.iloc[i, :]
            x[name2] = x[name2] + ' ' + x[name3]
            df.iloc[i, :] = x
        del df[name3] 
    if name4 in df:
        check = df[df[name4].notnull()].index.tolist()
        print(name4, '-', check)
        
        for i in check:
            x = df.iloc[i, :]
            x[name2] = x[name2] + ' ' + x[name4]
            df.iloc[i, :] = x
        del df[name4]
    return df

def cleanshirtsize(df, var):
    df[var] =df[var].str.lower() 
    df[var]= df[var].str.replace('large', 'l').str.replace('medium','m').str.replace('small','s').str.replace('médium','m')
    df[var]= df[var].str.replace('lx', 'xl').str.replace('x-l', 'xl').str.replace('2xl', 'xxl').replace('adultl', 'l').replace('2x','xxl')
    df[var]= df[var].str.replace('women’sxl', 'xl').str.replace('3xl','xxl').str.replace('m/l','l').str.replace('mors','m')
    df[var]= df[var].str.upper()
    return df

def cleanrace(df):
    v = 'Race'
    df[v] = df[v].str.lower().str.title().str.replace('Caucasian,White', 'White', regex=True)
    df[v]= df[v].str.replace('White,Caucasian', 'White', regex=True)
    return df

def transform(dforig):
    df = dforig.copy()
    
    #make all lower email
    df['Student Email'] = df['Student Email'].str.lower()
    df['Guardian 1 Email'] = df['Guardian 1 Email'].str.lower()
    df['Guardian 2 Email'] = df['Guardian 2 Email'].str.lower()
    #remove all nonnumbers in phonenumbers
    df['Student Phone'] = df['Student Phone'].str.replace('-', '').str.replace(' ', '')
    df['Guardian 1 Phone'] = df['Guardian 1 Phone'].str.replace('-', '').str.replace(' ', '')
    df['Guardian 2 Phone'] = df['Guardian 2 Phone'].str.replace('-', '').str.replace(' ', '')
    df['Emergency Contact'] = df['Emergency Contact'].str.replace('-', '')
    # remove all questions in sizes
    df['Shirt Size'] = df['Shirt Size'].str.replace('?', '', regex=True).str.replace(' ', '', regex=True)
    df['Short Size'] = df['Short Size'].str.replace('?', '', regex=True).str.replace(' ', '', regex=True)
    df['Guardian 1 Shirt Size'] = df['Guardian 1 Shirt Size'].str.replace('?', '', regex=True).str.replace(' ', '', regex=True)
    
    df['bday'] = df['Birthdate'].apply(lambda x: pd.to_datetime(x, errors='coerce'))
    print(df[df.bday.isnull()]['Birthdate'])
    
    medcheck = df[df["Medical Conditions"].notnull()].index.tolist()
        
        
    for i in medcheck:
        x = df.iloc[i, :]
        if pd.isna(x["Comments"]):
            x["Comments"] = 'Medical Conditions: ' + x["Medical Conditions"]
        else:
            print(x["Comments"])
            x["Comments"] = x["Comments"] + ' Medical Conditions: ' + x["Medical Conditions"]
        df.iloc[i, :] = x
    del df["Medical Conditions"] 
    
    #Split Names
    df = splitname(df, "Student Name")   
    df = splitname(df, "Guardian 1 Name")      
    df = splitname(df, "Guardian 2 Name")      
    
    df = cleanshirtsize(df, 'Guardian 1 Shirt Size')
    df = cleanrace(df)
    return df
transdf = transform(alldf)
# Out:
# 25     NaN
# 30     NaN
# 31     NaN
# 32     NaN
# 37     NaN
# 41     NaN
# 43     NaN
# 44     NaN
# 47     NaN
# 78     NaN
# 83     NaN
# 90     NaN
# 93     NaN
# 94     NaN
# 95     NaN
# 96     NaN
# 97     NaN
# 98     NaN
# 99     NaN
# 100    NaN
# 101    NaN
# 102    NaN
# 103    NaN
# 104    NaN
# 105    NaN
# 106    NaN
# 107    NaN
# 108    NaN
# 109    NaN
# 110    NaN
# 111    NaN
# 112    NaN
# 113    NaN
# 114    NaN
# 115    NaN
# 116    NaN
# 117    NaN
# 118    NaN
# 119    NaN
# 120    NaN
# 121    NaN
# 122    NaN
# 123    NaN
# Name: Birthdate, dtype: object
# Nickname is Katie
# Student Name3 - [28, 64, 97, 108]
# Student Name4 - [97]
# Guardian 1 Name3 - [9, 147]
# Guardian 2 Name3 - [18]
# <ipython-input-171-c7be4b36ae11>:68: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x["Comments"] = 'Medical Conditions: ' + x["Medical Conditions"]
# <ipython-input-171-c7be4b36ae11>:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x["Comments"] = x["Comments"] + ' Medical Conditions: ' + x["Medical Conditions"]
# <ipython-input-171-c7be4b36ae11>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x[name2] = x[name2] + ' ' + x[name3]
# <ipython-input-171-c7be4b36ae11>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x[name2] = x[name2] + ' ' + x[name4]

# %%
# for i in range(len(transdf)):
#     print(transdf.loc[i,'Guardian 1 Name'], transdf.loc[i,'Guardian 1 Phone'],'-',transdf.loc[i,'Guardian 2 Name'], transdf.loc[i,'Guardian 2 Phone'],'-',transdf.loc[i,'Emergency Contact'])
print(transdf[transdf['Guardian 2 Name1'].isnull()]['Guardian 2 Name1'])
print(transdf[transdf['Guardian 2 Name2'].isnull()]['Guardian 2 Name2'])
print(transdf.loc[101,:])
# Out:
# 7      NaN
# 8      NaN
# 10     NaN
# 14     NaN
# 16     NaN
# 17     NaN
# 19     NaN
# 20     NaN
# 25     NaN
# 30     NaN
# 31     NaN
# 32     NaN
# 37     NaN
# 40     NaN
# 41     NaN
# 43     NaN
# 44     NaN
# 45     NaN
# 47     NaN
# 49     NaN
# 51     NaN
# 59     NaN
# 70     NaN
# 76     NaN
# 78     NaN
# 79     NaN
# 83     NaN
# 85     NaN
# 88     NaN
# 90     NaN
# 93     NaN
# 94     NaN
# 95     NaN
# 96     NaN
# 98     NaN
# 101    NaN
# 102    NaN
# 105    NaN
# 108    NaN
# 109    NaN
# 110    NaN
# 111    NaN
# 114    NaN
# 116    NaN
# 119    NaN
# 120    NaN
# 127    NaN
# 128    NaN
# 130    NaN
# 133    NaN
# 135    NaN
# 142    NaN
# 143    NaN
# 144    NaN
# Name: Guardian 2 Name1, dtype: object
# 7       NaN
# 8       NaN
# 10      NaN
# 14      NaN
# 16      NaN
# 17      NaN
# 19      NaN
# 20      NaN
# 25      NaN
# 30      NaN
# 31      NaN
# 32      NaN
# 37      NaN
# 40      NaN
# 41      NaN
# 43      NaN
# 44      NaN
# 45      NaN
# 47      NaN
# 49      NaN
# 51      NaN
# 59      NaN
# 70      NaN
# 76      NaN
# 78      NaN
# 79      NaN
# 83      NaN
# 85      NaN
# 88      NaN
# 90      NaN
# 93      NaN
# 94      NaN
# 95      NaN
# 96      NaN
# 97     None
# 98      NaN
# 99     None
# 100    None
# 101     NaN
# 102     NaN
# 103    None
# 104    None
# 105     NaN
# 106    None
# 107    None
# 108     NaN
# 109     NaN
# 110     NaN
# 111     NaN
# 112    None
# 113    None
# 114     NaN
# 115    None
# 116     NaN
# 117    None
# 118    None
# 119     NaN
# 120     NaN
# 121    None
# 122    None
# 127     NaN
# 128     NaN
# 130     NaN
# 133     NaN
# 135     NaN
# 142     NaN
# 143     NaN
# 144     NaN
# Name: Guardian 2 Name2, dtype: object
# Student Name                             Anneyah Ramos
# Student Email            2022ramosan@students.mtwp.net
# Student Phone                               7176904342
# Student IG                                   9/22/2004
# Favorite Candy                            148 buch ave
# Birthdate                                          NaN
# Address                                    Puertorican
# Gender                                               S
# Race                                                 M
# Shirt Size                                AnnetteRamos
# Short Size                                717-330-2514
# Guardian 1 Name                     Annram10@yahoo.com
# Guardian 1 Phone                                   Mom
# Guardian 1 Email                                     m
# Guardian 1 Occupation                              NaN
# Guardian 1 Shirt Size                              NaN
# Guardian 2 Name                                    NaN
# Guardian 2 Phone                                   NaN
# Guardian 2 Email                                   NaN
# Guardian 2 Occupation         Annette/mom 717-560-8620
# Guardian 2 Shirt Size                              NaN
# Emergency Contact                                  NaN
# Comments                                           NaN
# School                                Manhiem Township
# Birthday                                        Female
# Gurdian 1 Occupation                               NaN
# Gurdian 1 Shirt Size                               NaN
# bday                                               NaT
# Student Name1                                  Anneyah
# Student Name2                                    Ramos
# Guardian 1 Name1                    Annram10@yahoo.com
# Guardian 1 Name2                                  None
# Guardian 2 Name1                                   NaN
# Guardian 2 Name2                                   NaN
# Name: 101, dtype: object

# %%
orderedcols = {'Student Name1':'fname', 'Student Name2':'lname', 'Student Email':'email', 
               'Student Phone':'phonenum','bday':'dob','School':'schoolid','Gender':'gender','Race':'race',
               'Address':'address','Shirt Size':'shirt','Short Size':'short','Student IG':'student_ig',
               'Favorite Candy':'favcandy','Guardian 1 Name1':'guard1fname','Guardian 1 Name2':'guard1lname',
               'Guardian 1 Phone':'guard1phonenum','Guardian 1 Email':'guard1email','Guardian 1 Occupation':'guard1occ',
               'Guardian 1 Shirt Size':'guard1shirt','Guardian 2 Name1':'guard2fname','Guardian 2 Name2':'guard2lname',
               'Guardian 2 Phone':'guard2phonenum','Guardian 2 Email':'guard2email','Guardian 2 Occupation':'guard2occ',
               'Guardian 2 Shirt Size':'guard2shirt','Emergency Contact':'emergcontact','Comments':'comments'}

# %%
transdf.columns
# Out:
# Index(['Student Name', 'Student Email', 'Student Phone', 'Student IG',
#        'Favorite Candy', 'Birthdate', 'Address', 'Gender', 'Race',
#        'Shirt Size', 'Short Size', 'Guardian 1 Name', 'Guardian 1 Phone',
#        'Guardian 1 Email', 'Guardian 1 Occupation', 'Guardian 1 Shirt Size',
#        'Guardian 2 Name', 'Guardian 2 Phone', 'Guardian 2 Email',
#        'Guardian 2 Occupation', 'Guardian 2 Shirt Size', 'Emergency Contact',
#        'Comments', 'School', 'Birthday', 'Gurdian 1 Occupation',
#        'Gurdian 1 Shirt Size', 'bday', 'Student Name1', 'Student Name2',
#        'Guardian 1 Name1', 'Guardian 1 Name2', 'Guardian 2 Name1',
#        'Guardian 2 Name2'],
#       dtype='object')

# %%
def cleantransdf(df):
    df.rename(orderedcols, axis=1, inplace=True)
cleantransdf(transdf)

# %%
transdf.head()
# Out:
#      Student Name                                email      phonenum  \
# 0  Alayna Morales  moralesaj1@students.columbiabsd.org  +17174157784
# 1  Andrew Eitnier              andrewcolbey@icloud.com  +17176693252
# 2   Ashton Paules    paulesab@students.columbiabsd.org  +17172091487
# 3    Carmen Cayol               carmensita1@icloud.com  +17176173496
# 4  Collin McCarty   mccartycp@students.columbiabsd.org  +17178088113
#
#           student_ig               favcandy   Birthdate  \
# 0    alayna__morales                 Reeses    2-Sep-03
# 1          _aeitnier                 Reeses   6/24/2003
# 2      ashton_paules  Any kind of chocolate  11/10/2003
# 3        _carmenn.__               Skittles  12/20/2003
# 4  collin_mccarty_14               Snickers    6/4/2004
#
#                                address  gender             race shirt short  \
# 0                   921 Ironville Pike  Female  White/ Hispanic     M     M
# 1    113 Locust St. Columbia, Pa 17512    Male            White   XXL   XXL
# 2  535 Maple Street Columbia, PA 17512    Male            White     M     M
# 3                     339 Union Street  Female         Hispanic     S     S
# 4                    1020 central ave.    Male            White     L     L
#
#        Guardian 1 Name guard1phonenum               guard1email  \
# 0          Kim Morales   +17174496802   morales25@embarmail.com
# 1  Christopher Eitnier   +17174353671  seandaeitmaher@gmail.com
# 2     Melissa Haldeman   +17173683091      mhaldeman@rettew.com
# 3      Evelyn Socarras   +17173304926           laeve74@aol.com
# 4          Ray McCarty   +17174059377    raymccarty@hotmail.com
#
#                       guard1occ guard1shirt    Guardian 2 Name guard2phonenum  \
# 0                           LPN           L  Christian Morales   +17174498747
# 1                      Pressman           L       Tina Eitnier            NaN
# 2               Risk management           S       Tom Haldeman   +17174717238
# 3  Director at Childcare center           M     Bladimir Cayol   +17173301393
# 4             Financial Manager          XL      Marcy McCarty   +17174059382
#
#                 guard2email                      guard2occ guard2shirt  \
# 0  morales25@embarqmail.com  LSC Communications press lead          XL
# 1                       NaN                            NaN           L
# 2     tomhaldeman@yahoo.com                          Sales          XL
# 3           laeve74@aol.com                            NaN         XXL
# 4  marcymccarty@hotmail.com                      Professor           M
#
#                      emergcontact  \
# 0          Kim Morales 7174496802
# 1  Amanda MaherEitnier 7172011653
# 2     Melissa Haldeman 7173683091
# 3    Evelyn Socarras (7173304926)
# 4       Marcy McCarty. 7174059382
#
#                                             comments  schoolid Birthday  \
# 0                                                NaN  Columbia      NaN
# 1  Medical Conditions: Lexapro for anxiety, Albut...  Columbia      NaN
# 2                                                NaN  Columbia      NaN
# 3                                                NaN  Columbia      NaN
# 4                                                NaN  Columbia      NaN
#
#   Gurdian 1 Occupation Gurdian 1 Shirt Size        dob   fname    lname  \
# 0                  NaN                  NaN 2003-09-02  Alayna  Morales
# 1                  NaN                  NaN 2003-06-24  Andrew  Eitnier
# 2                  NaN                  NaN 2003-11-10  Ashton   Paules
# 3                  NaN                  NaN 2003-12-20  Carmen    Cayol
# 4                  NaN                  NaN 2004-06-04  Collin  McCarty
#
#    guard1fname guard1lname guard2fname guard2lname
# 0          Kim     Morales   Christian     Morales
# 1  Christopher     Eitnier        Tina     Eitnier
# 2      Melissa    Haldeman         Tom    Haldeman
# 3       Evelyn    Socarras    Bladimir       Cayol
# 4          Ray     McCarty       Marcy     McCarty

# %%
def intphone(df, var):
    df[var] = '+1'+df[var]
intphone(transdf, 'phonenum')
intphone(transdf, 'guard1phonenum')
intphone(transdf, 'guard2phonenum')

# %%
transdf.to_csv('transdf2.csv')
